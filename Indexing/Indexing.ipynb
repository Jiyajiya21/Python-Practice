# %%
import pandas as pd
import seaborn as sns

# %%
 df = pd.read_csv(r"/Users/jiyadariyani/Documents/Github/Pandas Practice/Python-Practice/Indexing/Flavors.csv")

# %% [raw]
# df.head(5)

# %%
from IPython.display import display
display(df.head(5))
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1            Chocolate   Chocolate   Yes            8.8             7.6
# 2              Vanilla     Vanilla    No            4.7             5.0
# 3         Cookie Dough     Vanilla   Yes            6.9             6.5
# 4           Rocky Road   Chocolate   Yes            8.2             7.0
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2

# %% [markdown]
# ## Finding the specific data using its Location

# %%
df.loc[1]
# Out:
# Flavor            Chocolate
# Base Flavor       Chocolate
# Liked                   Yes
# Flavor Rating           8.8
# Texture Rating          7.6
# Total Rating           16.6
# Name: 1, dtype: object

# %% [markdown]
# ## Setting the Index as Flavor

# %%
df2 = df.set_index('Base Flavor')
df2
# Out:
#                              Flavor Liked  Flavor Rating  Texture Rating  \
# Base Flavor
# Vanilla         Mint Chocolate Chip   Yes           10.0             8.0
# Chocolate                 Chocolate   Yes            8.8             7.6
# Vanilla                     Vanilla    No            4.7             5.0
# Vanilla                Cookie Dough   Yes            6.9             6.5
# Chocolate                Rocky Road   Yes            8.2             7.0
# Vanilla                   Pistachio    No            2.3             3.4
# Vanilla                 Cake Batter   Yes            6.5             6.0
# Vanilla                  Neapolitan    No            3.8             5.0
# Chocolate    Chocolte Fudge Brownie   Yes            8.2             7.1
#
#              Total Rating
# Base Flavor
# Vanilla              18.0
# Chocolate            16.6
# Vanilla               9.7
# Vanilla              13.4
# Chocolate            15.2
# Vanilla               5.7
# ...

# %% [markdown]
# ## Finding the row where Flavor is Vanilla

# %%
d = df.loc[df['Flavor'] == 'Vanilla']
d
# Out:
#     Flavor Base Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# 2  Vanilla     Vanilla    No            4.7             5.0           9.7

# %% [markdown]
# ## Finding Total by Flavor

# %%
df = df.groupby('Flavor').sum()
df
# Out:
#                        Base Flavor Liked  Flavor Rating  Texture Rating  \
# Flavor
# Cake Batter                Vanilla   Yes            6.5             6.0
# Chocolate                Chocolate   Yes            8.8             7.6
# Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
# Cookie Dough               Vanilla   Yes            6.9             6.5
# Mint Chocolate Chip        Vanilla   Yes           10.0             8.0
# Neapolitan                 Vanilla    No            3.8             5.0
# Pistachio                  Vanilla    No            2.3             3.4
# Rocky Road               Chocolate   Yes            8.2             7.0
# Vanilla                    Vanilla    No            4.7             5.0
#
#                         Total Rating
# Flavor
# Cake Batter                     12.5
# Chocolate                       16.6
# Chocolte Fudge Brownie          15.3
# Cookie Dough                    13.4
# Mint Chocolate Chip             18.0
# ...

# %% [markdown]
# ## Aggregating on Specific Columns

# %%
df.groupby(['Base Flavor','Liked']).agg({'Flavor Rating':['mean','sum','count'], 'Total Rating' : ['mean','sum','count'] })
# Out:
#                   Flavor Rating             Total Rating
#                            mean   sum count         mean   sum count
# Base Flavor Liked
# Chocolate   Yes             8.4  25.2     3    15.700000  47.1     3
# Vanilla     No              3.6  10.8     3     8.066667  24.2     3
#             Yes             7.8  23.4     3    14.633333  43.9     3

# %%
sns.histplot(x = df['Flavor Rating'], kde = True, stat = "probability")
# Out:
# <Axes: xlabel='Flavor Rating', ylabel='Probability'>
